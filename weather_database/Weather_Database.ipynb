# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime
import requests
import time
from scipy.stats import linregress

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coords = list(lat_lngs)
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coords:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 783

# %%
# Starting URL for Weather Map API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_name = city_weather["name"]
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
                # Append the city information into city_data list.
        city_data.append({"City": city_name,
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | umm lajj
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | iberia
# Processing Record 5 of Set 1 | beringovskiy
# Processing Record 6 of Set 1 | nyrob
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 1 | baoning
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | marystown
# Processing Record 14 of Set 1 | lodwar
# Processing Record 15 of Set 1 | glendive
# Processing Record 16 of Set 1 | fortuna
# Processing Record 17 of Set 1 | vila velha
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | mahebourg
# Processing Record 20 of Set 1 | salalah
# Processing Record 21 of Set 1 | qinhuangdao
# Processing Record 22 of Set 1 | shuangcheng
# Processing Record 23 of Set 1 | wanlaweyn
# Processing Record 24 of Set 1 | umba
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | metro
# Processing Record 27 of Set 1 | chauk
# Processing Record 28 of Set 1 | bayir
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | beloha
# Processing Record 31 of Set 1 | abu samrah
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | lompoc
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | langham
# Processing Record 37 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 1 | port alfred
# Processing Record 39 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | nieuw nickerie
# Processing Record 42 of Set 1 | saskylakh
# Processing Record 43 of Set 1 | provideniya
# Processing Record 44 of Set 1 | yulara
# Processing Record 45 of Set 1 | lebu
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 1 | turbat
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | padang
# Processing Record 2 of Set 2 | san-pedro
# Processing Record 3 of Set 2 | matara
# Processing Record 4 of Set 2 | nanortalik
# Processing Record 5 of Set 2 | rikitea
# Processing Record 6 of Set 2 | gisborne
# Processing Record 7 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 2 | bredasdorp
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | lavrentiya
# Processing Record 11 of Set 2 | busselton
# Processing Record 12 of Set 2 | khatanga
# Processing Record 13 of Set 2 | chuy
# Processing Record 14 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 2 | saint-francois
# Processing Record 16 of Set 2 | ilulissat
# Processing Record 17 of Set 2 | kruisfontein
# Processing Record 18 of Set 2 | tasiilaq
# Processing Record 19 of Set 2 | gyula
# Processing Record 20 of Set 2 | dutse
# Processing Record 21 of Set 2 | cockburn town
# Processing Record 22 of Set 2 | ajdabiya
# Processing Record 23 of Set 2 | guarapari
# Processing Record 24 of Set 2 | ulaangom
# Processing Record 25 of Set 2 | saint-marc
# Processing Record 26 of Set 2 | jamestown
# Processing Record 27 of Set 2 | santa cruz
# Processing Record 28 of Set 2 | la venta del astillero
# Processing Record 29 of Set 2 | mananjary
# Processing Record 30 of Set 2 | georgetown
# Processing Record 31 of Set 2 | begunitsy
# Processing Record 32 of Set 2 | bengkulu
# Processing Record 33 of Set 2 | chara
# Processing Record 34 of Set 2 | gympie
# Processing Record 35 of Set 2 | castro
# Processing Record 36 of Set 2 | chapais
# Processing Record 37 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 2 | dikson
# Processing Record 39 of Set 2 | upernavik
# Processing Record 40 of Set 2 | bossembele
# City not found. Skipping...
# Processing Record 41 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 2 | pankovka
# Processing Record 43 of Set 2 | port elizabeth
# Processing Record 44 of Set 2 | saint-pierre
# Processing Record 45 of Set 2 | alekseyevka
# Processing Record 46 of Set 2 | butaritari
# Processing Record 47 of Set 2 | mayo
# Processing Record 48 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 2 | bataipora
# Processing Record 50 of Set 2 | orange cove
# Processing Record 1 of Set 3 | darasun
# Processing Record 2 of Set 3 | qostanay
# Processing Record 3 of Set 3 | harrison
# Processing Record 4 of Set 3 | sayyan
# Processing Record 5 of Set 3 | rognan
# Processing Record 6 of Set 3 | lashio
# Processing Record 7 of Set 3 | hami
# Processing Record 8 of Set 3 | chokurdakh
# Processing Record 9 of Set 3 | fairbanks
# Processing Record 10 of Set 3 | souillac
# Processing Record 11 of Set 3 | yamada
# Processing Record 12 of Set 3 | aloleng
# Processing Record 13 of Set 3 | arraial do cabo
# Processing Record 14 of Set 3 | kodiak
# Processing Record 15 of Set 3 | kaifeng
# Processing Record 16 of Set 3 | biltine
# Processing Record 17 of Set 3 | axim
# Processing Record 18 of Set 3 | nerchinskiy zavod
# Processing Record 19 of Set 3 | solnechnyy
# Processing Record 20 of Set 3 | ribeira grande
# Processing Record 21 of Set 3 | mlonggo
# Processing Record 22 of Set 3 | caravelas
# Processing Record 23 of Set 3 | altamont
# Processing Record 24 of Set 3 | the pas
# Processing Record 25 of Set 3 | aklavik
# Processing Record 26 of Set 3 | adrar
# Processing Record 27 of Set 3 | hinganghat
# Processing Record 28 of Set 3 | la troncal
# Processing Record 29 of Set 3 | shelburne
# Processing Record 30 of Set 3 | odessa
# Processing Record 31 of Set 3 | orlik
# Processing Record 32 of Set 3 | olafsvik
# Processing Record 33 of Set 3 | kalavad
# Processing Record 34 of Set 3 | harper
# Processing Record 35 of Set 3 | naron
# Processing Record 36 of Set 3 | sao filipe
# Processing Record 37 of Set 3 | talcahuano
# Processing Record 38 of Set 3 | kenora
# Processing Record 39 of Set 3 | clyde river
# Processing Record 40 of Set 3 | montemor-o-novo
# Processing Record 41 of Set 3 | port said
# Processing Record 42 of Set 3 | codrington
# Processing Record 43 of Set 3 | howard springs
# Processing Record 44 of Set 3 | vostok
# Processing Record 45 of Set 3 | severnoye
# Processing Record 46 of Set 3 | new norfolk
# Processing Record 47 of Set 3 | longyearbyen
# Processing Record 48 of Set 3 | lata
# Processing Record 49 of Set 3 | victoria
# Processing Record 50 of Set 3 | ancud
# Processing Record 1 of Set 4 | opobo
# City not found. Skipping...
# Processing Record 2 of Set 4 | whyalla
# Processing Record 3 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 4 of Set 4 | camaqua
# Processing Record 5 of Set 4 | qaanaaq
# Processing Record 6 of Set 4 | galesong
# Processing Record 7 of Set 4 | palana
# Processing Record 8 of Set 4 | nuuk
# Processing Record 9 of Set 4 | faanui
# Processing Record 10 of Set 4 | tiksi
# Processing Record 11 of Set 4 | huejuquilla el alto
# Processing Record 12 of Set 4 | richards bay
# Processing Record 13 of Set 4 | zaysan
# Processing Record 14 of Set 4 | tuktoyaktuk
# Processing Record 15 of Set 4 | bethel
# Processing Record 16 of Set 4 | klaksvik
# Processing Record 17 of Set 4 | mineiros
# Processing Record 18 of Set 4 | neiafu
# Processing Record 19 of Set 4 | khilok
# Processing Record 20 of Set 4 | carnarvon
# Processing Record 21 of Set 4 | maragogi
# Processing Record 22 of Set 4 | mount gambier
# Processing Record 23 of Set 4 | rocha
# Processing Record 24 of Set 4 | svetlogorsk
# Processing Record 25 of Set 4 | mount pleasant
# Processing Record 26 of Set 4 | barysh
# Processing Record 27 of Set 4 | yellowknife
# Processing Record 28 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 29 of Set 4 | angoche
# Processing Record 30 of Set 4 | vao
# Processing Record 31 of Set 4 | yerofey pavlovich
# Processing Record 32 of Set 4 | nortelandia
# Processing Record 33 of Set 4 | berbera
# Processing Record 34 of Set 4 | sergeyevka
# Processing Record 35 of Set 4 | kanbe
# Processing Record 36 of Set 4 | yar-sale
# Processing Record 37 of Set 4 | srednekolymsk
# Processing Record 38 of Set 4 | matsubase
# Processing Record 39 of Set 4 | socorro
# Processing Record 40 of Set 4 | mitu
# Processing Record 41 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 4 | tooele
# Processing Record 43 of Set 4 | san patricio
# Processing Record 44 of Set 4 | trinidad
# Processing Record 45 of Set 4 | cairns
# Processing Record 46 of Set 4 | portland
# Processing Record 47 of Set 4 | payo
# Processing Record 48 of Set 4 | kudahuvadhoo
# Processing Record 49 of Set 4 | sterling
# Processing Record 50 of Set 4 | mileai
# City not found. Skipping...
# Processing Record 1 of Set 5 | saint george
# Processing Record 2 of Set 5 | te anau
# Processing Record 3 of Set 5 | half moon bay
# Processing Record 4 of Set 5 | hofn
# Processing Record 5 of Set 5 | rawson
# Processing Record 6 of Set 5 | petropavlovka
# Processing Record 7 of Set 5 | bathsheba
# Processing Record 8 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 9 of Set 5 | cayenne
# Processing Record 10 of Set 5 | dholka
# Processing Record 11 of Set 5 | yuxia
# Processing Record 12 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 5 | myskhako
# Processing Record 14 of Set 5 | tiarei
# Processing Record 15 of Set 5 | laguna
# Processing Record 16 of Set 5 | darnah
# Processing Record 17 of Set 5 | airai
# Processing Record 18 of Set 5 | komsomolskiy
# Processing Record 19 of Set 5 | ponta do sol
# Processing Record 20 of Set 5 | kem
# Processing Record 21 of Set 5 | alekseyevsk
# Processing Record 22 of Set 5 | kurchum
# Processing Record 23 of Set 5 | buta
# Processing Record 24 of Set 5 | oranjemund
# Processing Record 25 of Set 5 | manokwari
# Processing Record 26 of Set 5 | saint-philippe
# Processing Record 27 of Set 5 | samarai
# Processing Record 28 of Set 5 | dongying
# Processing Record 29 of Set 5 | nouadhibou
# Processing Record 30 of Set 5 | coquimbo
# Processing Record 31 of Set 5 | antalaha
# Processing Record 32 of Set 5 | omsukchan
# Processing Record 33 of Set 5 | zhigansk
# Processing Record 34 of Set 5 | alamogordo
# Processing Record 35 of Set 5 | lukang
# Processing Record 36 of Set 5 | vardo
# Processing Record 37 of Set 5 | mehamn
# Processing Record 38 of Set 5 | abilene
# Processing Record 39 of Set 5 | tutoia
# Processing Record 40 of Set 5 | susehri
# Processing Record 41 of Set 5 | diamantino
# Processing Record 42 of Set 5 | cabedelo
# Processing Record 43 of Set 5 | parabel
# Processing Record 44 of Set 5 | nikolskoye
# Processing Record 45 of Set 5 | port macquarie
# Processing Record 46 of Set 5 | mar del plata
# Processing Record 47 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 5 | cherskiy
# Processing Record 49 of Set 5 | erenhot
# Processing Record 50 of Set 5 | alofi
# Processing Record 1 of Set 6 | thompson
# Processing Record 2 of Set 6 | la union
# Processing Record 3 of Set 6 | severo-kurilsk
# Processing Record 4 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 6 | wasilla
# Processing Record 6 of Set 6 | rena
# Processing Record 7 of Set 6 | port hardy
# Processing Record 8 of Set 6 | el mahalla el kubra
# City not found. Skipping...
# Processing Record 9 of Set 6 | kahului
# Processing Record 10 of Set 6 | vila franca do campo
# Processing Record 11 of Set 6 | norman wells
# Processing Record 12 of Set 6 | belaya gora
# Processing Record 13 of Set 6 | contamana
# Processing Record 14 of Set 6 | sinnamary
# Processing Record 15 of Set 6 | ucar
# Processing Record 16 of Set 6 | lyubeshiv
# City not found. Skipping...
# Processing Record 17 of Set 6 | almaznyy
# Processing Record 18 of Set 6 | tungor
# Processing Record 19 of Set 6 | terrace
# Processing Record 20 of Set 6 | bani walid
# Processing Record 21 of Set 6 | meiganga
# Processing Record 22 of Set 6 | hasaki
# Processing Record 23 of Set 6 | lodja
# Processing Record 24 of Set 6 | crab hill
# City not found. Skipping...
# Processing Record 25 of Set 6 | batemans bay
# Processing Record 26 of Set 6 | hamilton
# Processing Record 27 of Set 6 | taoudenni
# Processing Record 28 of Set 6 | moranbah
# Processing Record 29 of Set 6 | baranain
# Processing Record 30 of Set 6 | mayya
# Processing Record 31 of Set 6 | lagoa
# Processing Record 32 of Set 6 | pisco
# Processing Record 33 of Set 6 | torbay
# Processing Record 34 of Set 6 | thaton
# Processing Record 35 of Set 6 | saldanha
# Processing Record 36 of Set 6 | pemangkat
# Processing Record 37 of Set 6 | ixtapa
# Processing Record 38 of Set 6 | krasnoselkup
# Processing Record 39 of Set 6 | cabo san lucas
# Processing Record 40 of Set 6 | inzhavino
# Processing Record 41 of Set 6 | naranjito
# Processing Record 42 of Set 6 | formosa
# Processing Record 43 of Set 6 | kerki
# City not found. Skipping...
# Processing Record 44 of Set 6 | bambous virieux
# Processing Record 45 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 6 | flin flon
# Processing Record 47 of Set 6 | mudon
# Processing Record 48 of Set 6 | vetluga
# Processing Record 49 of Set 6 | durango
# Processing Record 50 of Set 6 | asau
# Processing Record 1 of Set 7 | pedernales
# Processing Record 2 of Set 7 | sechura
# Processing Record 3 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 4 of Set 7 | atasu
# Processing Record 5 of Set 7 | batagay-alyta
# Processing Record 6 of Set 7 | urfa
# City not found. Skipping...
# Processing Record 7 of Set 7 | sinarades
# Processing Record 8 of Set 7 | yinchuan
# Processing Record 9 of Set 7 | kiruna
# Processing Record 10 of Set 7 | krylovskaya
# Processing Record 11 of Set 7 | bilma
# Processing Record 12 of Set 7 | paita
# Processing Record 13 of Set 7 | ayaviri
# Processing Record 14 of Set 7 | pochutla
# Processing Record 15 of Set 7 | tautira
# Processing Record 16 of Set 7 | broome
# Processing Record 17 of Set 7 | piet retief
# Processing Record 18 of Set 7 | huarmey
# Processing Record 19 of Set 7 | mingoyo
# Processing Record 20 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 7 | pevek
# Processing Record 22 of Set 7 | libreville
# Processing Record 23 of Set 7 | makakilo city
# Processing Record 24 of Set 7 | gorontalo
# Processing Record 25 of Set 7 | talnakh
# Processing Record 26 of Set 7 | farah
# Processing Record 27 of Set 7 | malibu
# Processing Record 28 of Set 7 | ejura
# Processing Record 29 of Set 7 | rock sound
# Processing Record 30 of Set 7 | lasa
# Processing Record 31 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 7 | vestmannaeyjar
# Processing Record 33 of Set 7 | oktyabrskoye
# Processing Record 34 of Set 7 | narsaq
# Processing Record 35 of Set 7 | puerto narino
# Processing Record 36 of Set 7 | fort frances
# Processing Record 37 of Set 7 | shenzhen
# Processing Record 38 of Set 7 | dublin
# Processing Record 39 of Set 7 | mattru
# Processing Record 40 of Set 7 | montepuez
# Processing Record 41 of Set 7 | la ronge
# Processing Record 42 of Set 7 | gemena
# Processing Record 43 of Set 7 | cidreira
# Processing Record 44 of Set 7 | willowmore
# Processing Record 45 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 46 of Set 7 | zabkowice slaskie
# Processing Record 47 of Set 7 | turukhansk
# Processing Record 48 of Set 7 | kamaishi
# Processing Record 49 of Set 7 | eureka
# Processing Record 50 of Set 7 | bucerias
# Processing Record 1 of Set 8 | lisakovsk
# Processing Record 2 of Set 8 | esperance
# Processing Record 3 of Set 8 | marigot
# Processing Record 4 of Set 8 | mount isa
# Processing Record 5 of Set 8 | perth
# Processing Record 6 of Set 8 | hambantota
# Processing Record 7 of Set 8 | ampanihy
# Processing Record 8 of Set 8 | camacha
# Processing Record 9 of Set 8 | gijon
# Processing Record 10 of Set 8 | ranong
# Processing Record 11 of Set 8 | praya
# Processing Record 12 of Set 8 | sitka
# Processing Record 13 of Set 8 | baykit
# Processing Record 14 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 15 of Set 8 | kaitangata
# Processing Record 16 of Set 8 | iwanai
# Processing Record 17 of Set 8 | buala
# Processing Record 18 of Set 8 | leshukonskoye
# Processing Record 19 of Set 8 | sisimiut
# Processing Record 20 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 21 of Set 8 | yerbogachen
# Processing Record 22 of Set 8 | katsuura
# Processing Record 23 of Set 8 | staryy nadym
# Processing Record 24 of Set 8 | guerrero negro
# Processing Record 25 of Set 8 | russkaya polyana
# Processing Record 26 of Set 8 | jurm
# Processing Record 27 of Set 8 | uniontown
# Processing Record 28 of Set 8 | takoradi
# Processing Record 29 of Set 8 | simao
# Processing Record 30 of Set 8 | itarema
# Processing Record 31 of Set 8 | varadero
# Processing Record 32 of Set 8 | chernyshevskiy
# Processing Record 33 of Set 8 | ostersund
# Processing Record 34 of Set 8 | morehead
# Processing Record 35 of Set 8 | najran
# Processing Record 36 of Set 8 | pangody
# Processing Record 37 of Set 8 | ye
# City not found. Skipping...
# Processing Record 38 of Set 8 | carutapera
# Processing Record 39 of Set 8 | antofagasta
# Processing Record 40 of Set 8 | westerkappeln
# Processing Record 41 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 42 of Set 8 | la orilla
# Processing Record 43 of Set 8 | progreso
# Processing Record 44 of Set 8 | altus
# Processing Record 45 of Set 8 | karasjok
# Processing Record 46 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 47 of Set 8 | bandarbeyla
# Processing Record 48 of Set 8 | lakota
# Processing Record 49 of Set 8 | chengde
# Processing Record 50 of Set 8 | qaqortoq
# Processing Record 1 of Set 9 | maua
# Processing Record 2 of Set 9 | evensk
# Processing Record 3 of Set 9 | verkhnyaya khava
# Processing Record 4 of Set 9 | auki
# Processing Record 5 of Set 9 | natitingou
# Processing Record 6 of Set 9 | anjozorobe
# Processing Record 7 of Set 9 | sfantu gheorghe
# Processing Record 8 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 9 of Set 9 | rio grande
# Processing Record 10 of Set 9 | mundo nuevo
# Processing Record 11 of Set 9 | carahue
# Processing Record 12 of Set 9 | honiara
# Processing Record 13 of Set 9 | ibanda
# Processing Record 14 of Set 9 | pascagoula
# Processing Record 15 of Set 9 | tura
# Processing Record 16 of Set 9 | ust-tsilma
# Processing Record 17 of Set 9 | korla
# Processing Record 18 of Set 9 | husavik
# Processing Record 19 of Set 9 | valparaiso
# Processing Record 20 of Set 9 | dongsheng
# Processing Record 21 of Set 9 | pecos
# Processing Record 22 of Set 9 | vreed en hoop
# City not found. Skipping...
# Processing Record 23 of Set 9 | san cristobal
# Processing Record 24 of Set 9 | port lincoln
# Processing Record 25 of Set 9 | candolim
# Processing Record 26 of Set 9 | forbes
# Processing Record 27 of Set 9 | peniche
# Processing Record 28 of Set 9 | akyab
# Processing Record 29 of Set 9 | luwuk
# Processing Record 30 of Set 9 | deputatskiy
# Processing Record 31 of Set 9 | rio rancho
# Processing Record 32 of Set 9 | fukue
# Processing Record 33 of Set 9 | karak
# Processing Record 34 of Set 9 | loei
# Processing Record 35 of Set 9 | aginskoye
# Processing Record 36 of Set 9 | zastron
# Processing Record 37 of Set 9 | labuan
# Processing Record 38 of Set 9 | mezen
# Processing Record 39 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 40 of Set 9 | aquiraz
# Processing Record 41 of Set 9 | colares
# Processing Record 42 of Set 9 | havre-saint-pierre
# Processing Record 43 of Set 9 | ziro
# Processing Record 44 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 45 of Set 9 | angouleme
# Processing Record 46 of Set 9 | eyl
# Processing Record 47 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 9 | suntar
# Processing Record 49 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 50 of Set 9 | russell
# Processing Record 1 of Set 10 | alugan
# Processing Record 2 of Set 10 | tomatlan
# Processing Record 3 of Set 10 | dehloran
# Processing Record 4 of Set 10 | san remo
# Processing Record 5 of Set 10 | ayolas
# Processing Record 6 of Set 10 | general pico
# Processing Record 7 of Set 10 | calvia
# Processing Record 8 of Set 10 | liverpool
# Processing Record 9 of Set 10 | sibolga
# Processing Record 10 of Set 10 | meulaboh
# Processing Record 11 of Set 10 | talavera de la reina
# Processing Record 12 of Set 10 | east london
# Processing Record 13 of Set 10 | syamzha
# Processing Record 14 of Set 10 | moa
# Processing Record 15 of Set 10 | naze
# Processing Record 16 of Set 10 | san ramon
# Processing Record 17 of Set 10 | lengshuitan
# Processing Record 18 of Set 10 | ostrovnoy
# Processing Record 19 of Set 10 | port keats
# Processing Record 20 of Set 10 | nenjiang
# Processing Record 21 of Set 10 | coihaique
# Processing Record 22 of Set 10 | seoul
# Processing Record 23 of Set 10 | muzhi
# Processing Record 24 of Set 10 | quatre cocos
# Processing Record 25 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 26 of Set 10 | ola
# Processing Record 27 of Set 10 | manthani
# Processing Record 28 of Set 10 | beckley
# Processing Record 29 of Set 10 | shelton
# Processing Record 30 of Set 10 | kavieng
# Processing Record 31 of Set 10 | stornoway
# Processing Record 32 of Set 10 | sabalgarh
# Processing Record 33 of Set 10 | zapolyarnyy
# Processing Record 34 of Set 10 | susurluk
# Processing Record 35 of Set 10 | daru
# Processing Record 36 of Set 10 | safford
# Processing Record 37 of Set 10 | gat
# Processing Record 38 of Set 10 | inuvik
# Processing Record 39 of Set 10 | mazatlan
# Processing Record 40 of Set 10 | sesimbra
# Processing Record 41 of Set 10 | aykhal
# Processing Record 42 of Set 10 | maham
# Processing Record 43 of Set 10 | ramon
# Processing Record 44 of Set 10 | hays
# Processing Record 45 of Set 10 | iranshahr
# Processing Record 46 of Set 10 | gazli
# Processing Record 47 of Set 10 | camargo
# Processing Record 48 of Set 10 | iqaluit
# Processing Record 49 of Set 10 | istria
# Processing Record 50 of Set 10 | kloulklubed
# Processing Record 1 of Set 11 | baruun-urt
# Processing Record 2 of Set 11 | suifenhe
# Processing Record 3 of Set 11 | cadereyta
# Processing Record 4 of Set 11 | mastic beach
# Processing Record 5 of Set 11 | mecca
# Processing Record 6 of Set 11 | saint-joseph
# Processing Record 7 of Set 11 | clemson
# Processing Record 8 of Set 11 | constantine
# Processing Record 9 of Set 11 | acuna
# City not found. Skipping...
# Processing Record 10 of Set 11 | shkotovo-26
# City not found. Skipping...
# Processing Record 11 of Set 11 | tilichiki
# Processing Record 12 of Set 11 | namibe
# Processing Record 13 of Set 11 | nacogdoches
# Processing Record 14 of Set 11 | kampong thum
# Processing Record 15 of Set 11 | geraldton
# Processing Record 16 of Set 11 | youkounkoun
# Processing Record 17 of Set 11 | saint-avold
# Processing Record 18 of Set 11 | gornji milanovac
# Processing Record 19 of Set 11 | ponta delgada
# Processing Record 20 of Set 11 | ebano
# City not found. Skipping...
# Processing Record 21 of Set 11 | devonport
# Processing Record 22 of Set 11 | makinsk
# Processing Record 23 of Set 11 | port hedland
# Processing Record 24 of Set 11 | neryungri
# Processing Record 25 of Set 11 | razdolinsk
# Processing Record 26 of Set 11 | toora-khem
# Processing Record 27 of Set 11 | tual
# Processing Record 28 of Set 11 | kosonsoy
# Processing Record 29 of Set 11 | dieppe
# Processing Record 30 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 31 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 32 of Set 11 | chalus
# Processing Record 33 of Set 11 | okhotsk
# Processing Record 34 of Set 11 | plettenberg bay
# Processing Record 35 of Set 11 | puerto escondido
# Processing Record 36 of Set 11 | medvedka
# Processing Record 37 of Set 11 | port blair
# Processing Record 38 of Set 11 | ahuimanu
# Processing Record 39 of Set 11 | poum
# Processing Record 40 of Set 11 | isangel
# Processing Record 41 of Set 11 | bonthe
# Processing Record 42 of Set 11 | rafai
# Processing Record 43 of Set 11 | gdov
# Processing Record 44 of Set 11 | ojuelos de jalisco
# Processing Record 45 of Set 11 | necochea
# Processing Record 46 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 47 of Set 11 | corpus christi
# Processing Record 48 of Set 11 | gambo
# Processing Record 49 of Set 11 | karimnagar
# Processing Record 50 of Set 11 | luoyang
# Processing Record 1 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 12 | hervey bay
# Processing Record 3 of Set 12 | nuevo progreso
# Processing Record 4 of Set 12 | concarneau
# Processing Record 5 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 12 | fort nelson
# Processing Record 7 of Set 12 | puerto el triunfo
# Processing Record 8 of Set 12 | upata
# Processing Record 9 of Set 12 | kajaani
# Processing Record 10 of Set 12 | nome
# Processing Record 11 of Set 12 | berlevag
# Processing Record 12 of Set 12 | puerto del rosario
# Processing Record 13 of Set 12 | leningradskiy
# Processing Record 14 of Set 12 | tynda
# Processing Record 15 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 16 of Set 12 | erzurum
# Processing Record 17 of Set 12 | great yarmouth
# Processing Record 18 of Set 12 | ha giang
# Processing Record 19 of Set 12 | labytnangi
# Processing Record 20 of Set 12 | tarauaca
# Processing Record 21 of Set 12 | svrljig
# Processing Record 22 of Set 12 | las vegas
# Processing Record 23 of Set 12 | yurya
# City not found. Skipping...
# Processing Record 24 of Set 12 | ryotsu
# Processing Record 25 of Set 12 | sao gabriel da cachoeira
# Processing Record 26 of Set 12 | saint-augustin
# Processing Record 27 of Set 12 | flinders
# Processing Record 28 of Set 12 | chaihe
# Processing Record 29 of Set 12 | linjiang
# Processing Record 30 of Set 12 | pasni
# Processing Record 31 of Set 12 | jalu
# Processing Record 32 of Set 12 | baherden
# Processing Record 33 of Set 12 | turmalina
# Processing Record 34 of Set 12 | gewane
# Processing Record 35 of Set 12 | casper
# Processing Record 36 of Set 12 | chambas
# Processing Record 37 of Set 12 | pangai
# Processing Record 38 of Set 12 | westport
# Processing Record 39 of Set 12 | road town
# Processing Record 40 of Set 12 | madona
# Processing Record 41 of Set 12 | san quintin
# Processing Record 42 of Set 12 | gorin
# Processing Record 43 of Set 12 | motygino
# Processing Record 44 of Set 12 | undory
# Processing Record 45 of Set 12 | sao joao da barra
# Processing Record 46 of Set 12 | birao
# Processing Record 47 of Set 12 | haines junction
# Processing Record 48 of Set 12 | faya
# Processing Record 49 of Set 12 | katobu
# Processing Record 50 of Set 12 | ternate
# Processing Record 1 of Set 13 | severo-yeniseyskiy
# Processing Record 2 of Set 13 | rodrigues alves
# Processing Record 3 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 4 of Set 13 | tumbagaan
# Processing Record 5 of Set 13 | huilong
# Processing Record 6 of Set 13 | neufchateau
# Processing Record 7 of Set 13 | san andres
# Processing Record 8 of Set 13 | pandan
# Processing Record 9 of Set 13 | derzhavinsk
# Processing Record 10 of Set 13 | bloomfield
# Processing Record 11 of Set 13 | labuhan
# Processing Record 12 of Set 13 | dera din panah
# City not found. Skipping...
# Processing Record 13 of Set 13 | johannesburg
# Processing Record 14 of Set 13 | west plains
# Processing Record 15 of Set 13 | fereydunshahr
# Processing Record 16 of Set 13 | pangnirtung
# Processing Record 17 of Set 13 | san lorenzo
# Processing Record 18 of Set 13 | lafiagi
# Processing Record 19 of Set 13 | kirkwall
# Processing Record 20 of Set 13 | ossora
# Processing Record 21 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 22 of Set 13 | balakovo
# Processing Record 23 of Set 13 | warrnambool
# Processing Record 24 of Set 13 | ginir
# Processing Record 25 of Set 13 | bhag
# Processing Record 26 of Set 13 | el fuerte
# Processing Record 27 of Set 13 | rodionovo-nesvetayskaya
# Processing Record 28 of Set 13 | shcholkine
# City not found. Skipping...
# Processing Record 29 of Set 13 | baleno
# Processing Record 30 of Set 13 | hohhot
# Processing Record 31 of Set 13 | ligayan
# Processing Record 32 of Set 13 | burgdorf
# Processing Record 33 of Set 13 | tuatapere
# Processing Record 34 of Set 13 | meghri
# Processing Record 35 of Set 13 | saint-michel-des-saints
# Processing Record 36 of Set 13 | guadix
# Processing Record 37 of Set 13 | cascais
# Processing Record 38 of Set 13 | port arthur
# Processing Record 39 of Set 13 | lukh
# Processing Record 40 of Set 13 | kumluca
# Processing Record 41 of Set 13 | lazaro cardenas
# Processing Record 42 of Set 13 | constancia
# Processing Record 43 of Set 13 | sulangan
# Processing Record 44 of Set 13 | vrangel
# Processing Record 45 of Set 13 | burgeo
# Processing Record 46 of Set 13 | grand gaube
# Processing Record 47 of Set 13 | yumen
# Processing Record 48 of Set 13 | rio branco
# Processing Record 49 of Set 13 | bon air
# Processing Record 50 of Set 13 | chala
# Processing Record 1 of Set 14 | veraval
# Processing Record 2 of Set 14 | balaka
# Processing Record 3 of Set 14 | chaumont
# Processing Record 4 of Set 14 | yenagoa
# Processing Record 5 of Set 14 | batagay
# Processing Record 6 of Set 14 | kulhudhuffushi
# Processing Record 7 of Set 14 | constitucion
# Processing Record 8 of Set 14 | touros
# Processing Record 9 of Set 14 | thinadhoo
# Processing Record 10 of Set 14 | inhambane
# Processing Record 11 of Set 14 | muros
# Processing Record 12 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 13 of Set 14 | iskateley
# Processing Record 14 of Set 14 | mutis
# Processing Record 15 of Set 14 | ardmore
# Processing Record 16 of Set 14 | den helder
# Processing Record 17 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 18 of Set 14 | turayf
# Processing Record 19 of Set 14 | henties bay
# Processing Record 20 of Set 14 | zachagansk
# City not found. Skipping...
# Processing Record 21 of Set 14 | gurupa
# Processing Record 22 of Set 14 | arkhipo-osipovka
# Processing Record 23 of Set 14 | hit
# Processing Record 24 of Set 14 | eskil
# Processing Record 25 of Set 14 | port-gentil
# Processing Record 26 of Set 14 | franklin
# Processing Record 27 of Set 14 | praia da vitoria
# Processing Record 28 of Set 14 | the valley
# Processing Record 29 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 30 of Set 14 | pemba
# Processing Record 31 of Set 14 | coihueco
# Processing Record 32 of Set 14 | storozhevaya
# Processing Record 33 of Set 14 | porto belo
# Processing Record 34 of Set 14 | kitimat
# Processing Record 35 of Set 14 | leopold
# Processing Record 36 of Set 14 | shache
# Processing Record 37 of Set 14 | sabaudia
# Processing Record 38 of Set 14 | lima
# Processing Record 39 of Set 14 | jinchang
# Processing Record 40 of Set 14 | borogontsy
# Processing Record 41 of Set 14 | great falls
# Processing Record 42 of Set 14 | ramos arizpe
# Processing Record 43 of Set 14 | morondava
# Processing Record 44 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 45 of Set 14 | roma
# Processing Record 46 of Set 14 | pavino
# Processing Record 47 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 48 of Set 14 | shingu
# Processing Record 49 of Set 14 | romitan
# Processing Record 50 of Set 14 | dotnuva
# Processing Record 1 of Set 15 | kiama
# Processing Record 2 of Set 15 | kalmunai
# Processing Record 3 of Set 15 | bulgan
# Processing Record 4 of Set 15 | beirut
# Processing Record 5 of Set 15 | sumbe
# Processing Record 6 of Set 15 | ilo
# Processing Record 7 of Set 15 | alyangula
# Processing Record 8 of Set 15 | fuxin
# Processing Record 9 of Set 15 | kismayo
# Processing Record 10 of Set 15 | haveli
# Processing Record 11 of Set 15 | egvekinot
# Processing Record 12 of Set 15 | tucuman
# Processing Record 13 of Set 15 | huangchuan
# Processing Record 14 of Set 15 | los llanos de aridane
# Processing Record 15 of Set 15 | ijaki
# City not found. Skipping...
# Processing Record 16 of Set 15 | rexburg
# Processing Record 17 of Set 15 | kodinsk
# Processing Record 18 of Set 15 | la macarena
# Processing Record 19 of Set 15 | bohmte
# Processing Record 20 of Set 15 | catuday
# Processing Record 21 of Set 15 | feijo
# Processing Record 22 of Set 15 | ornskoldsvik
# Processing Record 23 of Set 15 | binika
# Processing Record 24 of Set 15 | omboue
# Processing Record 25 of Set 15 | aljezur
# Processing Record 26 of Set 15 | along
# Processing Record 27 of Set 15 | acajutla
# Processing Record 28 of Set 15 | baghmara
# Processing Record 29 of Set 15 | vilyuysk
# Processing Record 30 of Set 15 | igarka
# Processing Record 31 of Set 15 | marsaxlokk
# Processing Record 32 of Set 15 | avanigadda
# Processing Record 33 of Set 15 | kemi
# Processing Record 34 of Set 15 | akureyri
# Processing Record 35 of Set 15 | dauphin
# Processing Record 36 of Set 15 | todos santos
# Processing Record 37 of Set 15 | waw
# Processing Record 38 of Set 15 | mitsamiouli
# Processing Record 39 of Set 15 | wahiawa
# Processing Record 40 of Set 15 | ayios vasilios
# Processing Record 41 of Set 15 | jinji
# Processing Record 42 of Set 15 | north bend
# Processing Record 43 of Set 15 | bud
# Processing Record 44 of Set 15 | itaueira
# Processing Record 45 of Set 15 | kununurra
# Processing Record 46 of Set 15 | buin
# Processing Record 47 of Set 15 | sheridan
# Processing Record 48 of Set 15 | broken hill
# Processing Record 49 of Set 15 | le port
# Processing Record 50 of Set 15 | kanniyakumari
# Processing Record 1 of Set 16 | falakata
# Processing Record 2 of Set 16 | tlapehuala
# Processing Record 3 of Set 16 | kollam
# Processing Record 4 of Set 16 | karasburg
# Processing Record 5 of Set 16 | araripe
# Processing Record 6 of Set 16 | abong mbang
# Processing Record 7 of Set 16 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 16 | alamosa
# Processing Record 9 of Set 16 | tomohon
# Processing Record 10 of Set 16 | puerto ayacucho
# Processing Record 11 of Set 16 | wageningen
# Processing Record 12 of Set 16 | goderich
# Processing Record 13 of Set 16 | saurimo
# Processing Record 14 of Set 16 | ishigaki
# Processing Record 15 of Set 16 | novo selo
# Processing Record 16 of Set 16 | belmonte
# Processing Record 17 of Set 16 | hovd
# Processing Record 18 of Set 16 | gwanda
# Processing Record 19 of Set 16 | abu dhabi
# Processing Record 20 of Set 16 | abha
# Processing Record 21 of Set 16 | roebourne
# Processing Record 22 of Set 16 | teya
# Processing Record 23 of Set 16 | zhangye
# Processing Record 24 of Set 16 | santa cruz de tenerife
# Processing Record 25 of Set 16 | spasskoye
# Processing Record 26 of Set 16 | sur
# Processing Record 27 of Set 16 | liku
# Processing Record 28 of Set 16 | anadyr
# Processing Record 29 of Set 16 | jizan
# Processing Record 30 of Set 16 | januaria
# Processing Record 31 of Set 16 | isla vista
# Processing Record 32 of Set 16 | university place
# Processing Record 33 of Set 16 | ocos
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Barrow',
#   'Country': 'US',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 28.42,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 19.57,
#   'Current Description': 'mist'},
#  {'City': 'Umluj',
#   'Country': 'SA',
#   'Lat': 25.0213,
#   'Lng': 37.2685,
#   'Max Temp': 85.05,
#   'Humidity': 54,
#   'Cloudiness': 97,
#   'Wind Speed': 4.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 78.71,
#   'Humidity': 78,
#   'Cloudiness': 4,
#   'Wind Speed': 21.16,
#   'Current Description': 'clear sky'},
#  {'City': 'Iberia',
#   'Country': 'US',
#   'Lat': 29.9502,
#   'Lng': -91.7507,
#   'Max Temp': 76.96,
#   'Humidity': 43,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Beringovskiy',
#   'Country': 'RU',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': 6.53,
#   'Humidity': 92,
#   'Cloudiness': 97,
#   'Wind Speed': 12.59,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nyrob',
#   'Country': 'RU',
#   'Lat': 60.733,
#   'Lng': 56.7202,
#   'Max Temp': 37.45,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 8.68,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 49.87,
#   'Humidity': 57,
#   'Cloudiness': 82,
#   'Wind Speed': 3.98,
#   'Current Description': 'light rain'},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 56.86,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 75.25,
#   'Humidity': 69,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Current Description': 'light rain'},
#  {'City': 'Baoning',
#   'Country': 'CN',
#   'Lat': 25.3378,
#   'Lng': 110.026,
#   'Max Temp': 60.66,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 4.47,
#   'Current Description': 'mist'},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 78.76,
#   'Humidity': 79,
#   'Cloudiness': 43,
#   'Wind Speed': 8.9,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Marystown',
#   'Country': 'CA',
#   'Lat': 47.1666,
#   'Lng': -55.1483,
#   'Max Temp': 46.85,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lodwar',
#   'Country': 'KE',
#   'Lat': 3.1191,
#   'Lng': 35.5973,
#   'Max Temp': 88.7,
#   'Humidity': 32,
#   'Cloudiness': 80,
#   'Wind Speed': 21.65,
#   'Current Description': 'broken clouds'},
#  {'City': 'Glendive',
#   'Country': 'US',
#   'Lat': 47.1053,
#   'Lng': -104.7125,
#   'Max Temp': 42.69,
#   'Humidity': 48,
#   'Cloudiness': 1,
#   'Wind Speed': 14.97,
#   'Current Description': 'clear sky'},
#  {'City': 'Fortuna',
#   'Country': 'US',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 66.92,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 7,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Vila Velha',
#   'Country': 'BR',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 71.55,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Current Description': 'light rain'},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 79.2,
#   'Humidity': 78,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Current Description': 'clear sky'},
#  {'City': 'Mahébourg',
#   'Country': 'MU',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 72.25,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Current Description': 'broken clouds'},
#  {'City': 'Salalah',
#   'Country': 'OM',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 77.09,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Qinhuangdao',
#   'Country': 'CN',
#   'Lat': 39.9317,
#   'Lng': 119.5883,
#   'Max Temp': 43.11,
#   'Humidity': 54,
#   'Cloudiness': 1,
#   'Wind Speed': 5.32,
#   'Current Description': 'clear sky'},
#  {'City': 'Shuangcheng',
#   'Country': 'CN',
#   'Lat': 45.35,
#   'Lng': 126.2833,
#   'Max Temp': 33.48,
#   'Humidity': 91,
#   'Cloudiness': 79,
#   'Wind Speed': 6.22,
#   'Current Description': 'broken clouds'},
#  {'City': 'Wanlaweyn',
#   'Country': 'SO',
#   'Lat': 2.6185,
#   'Lng': 44.8938,
#   'Max Temp': 78.82,
#   'Humidity': 73,
#   'Cloudiness': 2,
#   'Wind Speed': 13.18,
#   'Current Description': 'clear sky'},
#  {'City': 'Umba',
#   'Country': 'RU',
#   'Lat': 66.6871,
#   'Lng': 34.3429,
#   'Max Temp': 34.57,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 10.71,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Metro',
#   'Country': 'ID',
#   'Lat': -5.1131,
#   'Lng': 105.3067,
#   'Max Temp': 76.3,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 3.06,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chauk',
#   'Country': 'MM',
#   'Lat': 20.8833,
#   'Lng': 94.8167,
#   'Max Temp': 76.12,
#   'Humidity': 91,
#   'Cloudiness': 67,
#   'Wind Speed': 3.22,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bayir',
#   'Country': 'TR',
#   'Lat': 37.2687,
#   'Lng': 28.2167,
#   'Max Temp': 57.72,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.51,
#   'Current Description': 'moderate rain'},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 62.91,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 10.29,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Beloha',
#   'Country': 'MG',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 73.33,
#   'Humidity': 74,
#   'Cloudiness': 98,
#   'Wind Speed': 4.61,
#   'Current Description': 'light rain'},
#  {'City': 'Abu Samrah',
#   'Country': 'SY',
#   'Lat': 35.3029,
#   'Lng': 37.1841,
#   'Max Temp': 69.22,
#   'Humidity': 51,
#   'Cloudiness': 98,
#   'Wind Speed': 15.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 82.31,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 18.25,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 77.16,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Current Description': 'few clouds'},
#  {'City': 'Lompoc',
#   'Country': 'US',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 71.69,
#   'Humidity': 62,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 55.26,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Langham',
#   'Country': 'CA',
#   'Lat': 52.3668,
#   'Lng': -106.9679,
#   'Max Temp': 38.01,
#   'Humidity': 43,
#   'Cloudiness': 16,
#   'Wind Speed': 11.65,
#   'Current Description': 'few clouds'},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 67.12,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 17.02,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 60.46,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 11.03,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nieuw Nickerie',
#   'Country': 'SR',
#   'Lat': 5.95,
#   'Lng': -56.9833,
#   'Max Temp': 82.38,
#   'Humidity': 72,
#   'Cloudiness': 81,
#   'Wind Speed': 10.31,
#   'Current Description': 'broken clouds'},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 8.51,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 5.06,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 19.51,
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 8.95,
#   'Current Description': 'few clouds'},
#  {'City': 'Yulara',
#   'Country': 'AU',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 64.24,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 2.3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 57.99,
#   'Humidity': 76,
#   'Cloudiness': 97,
#   'Wind Speed': 8.14,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 81.25,
#   'Humidity': 67,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 57.31,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Turbat',
#   'Country': 'PK',
#   'Lat': 26.0023,
#   'Lng': 63.044,
#   'Max Temp': 80.8,
#   'Humidity': 16,
#   'Cloudiness': 0,
#   'Wind Speed': 24.52,
#   'Current Description': 'clear sky'},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 64.11,
#   'Humidity': 81,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Current Description': 'few clouds'},
#  {'City': 'Padang',
#   'Country': 'ID',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 75.81,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.96,
#   'Current Description': 'overcast clouds'},
#  {'City': 'San-Pédro',
#   'Country': 'CI',
#   'Lat': 4.7485,
#   'Lng': -6.6363,
#   'Max Temp': 78.46,
#   'Humidity': 86,
#   'Cloudiness': 43,
#   'Wind Speed': 8.63,
#   'Current Description': 'light rain'},
#  {'City': 'Matara',
#   'Country': 'LK',
#   'Lat': 5.9485,
#   'Lng': 80.5353,
#   'Max Temp': 77.14,
#   'Humidity': 89,
#   'Cloudiness': 89,
#   'Wind Speed': 3.2,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nanortalik',
#   'Country': 'GL',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 33.87,
#   'Humidity': 74,
#   'Cloudiness': 71,
#   'Wind Speed': 11.03,
#   'Current Description': 'broken clouds'},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 73.8,
#   'Humidity': 87,
#   'Cloudiness': 78,
#   'Wind Speed': 6.4,
#   'Current Description': 'light rain'},
#  {'City': 'Gisborne',
#   'Country': 'NZ',
#   'Lat': -38.6533,
#   'Lng': 178.0042,
#   'Max Temp': 61.95,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 59.29,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 7.16,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 51.57,
#   'Humidity': 69,
#   'Cloudiness': 92,
#   'Wind Speed': 20.92,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lavrentiya',
#   'Country': 'RU',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 12.36,
#   'Humidity': 81,
#   'Cloudiness': 4,
#   'Wind Speed': 12.1,
#   'Current Description': 'clear sky'},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 54.05,
#   'Humidity': 73,
#   'Cloudiness': 94,
#   'Wind Speed': 19.98,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Khatanga',
#   'Country': 'RU',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 5.5,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 10.29,
#   'Current Description': 'light snow'},
#  {'City': 'Chui',
#   'Country': 'UY',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 71.49,
#   'Humidity': 78,
#   'Cloudiness': 46,
#   'Wind Speed': 9.93,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Saint-François',
#   'Country': 'FR',
#   'Lat': 46.4154,
#   'Lng': 3.9054,
#   'Max Temp': 65.64,
#   'Humidity': 59,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ilulissat',
#   'Country': 'GL',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 32.02,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Current Description': 'snow'},
#  {'City': 'Kruisfontein',
#   'Country': 'ZA',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 69.89,
#   'Humidity': 86,
#   'Cloudiness': 70,
#   'Wind Speed': 5.68,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 26.76,
#   'Humidity': 61,
#   'Cloudiness': 98,
#   'Wind Speed': 4.72,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gyula',
#   'Country': 'HU',
#   'Lat': 46.65,
#   'Lng': 21.2833,
#   'Max Temp': 46.62,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 4.18,
#   'Current Description': 'clear sky'},
#  {'City': 'Dutse',
#   'Country': 'NG',
#   'Lat': 11.7594,
#   'Lng': 9.3392,
#   'Max Temp': 80.85,
#   'Humidity': 16,
#   'Cloudiness': 100,
#   'Wind Speed': 5.03,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cockburn Town',
#   'Country': 'TC',
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 82.31,
#   'Humidity': 69,
#   'Cloudiness': 39,
#   'Wind Speed': 7.61,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ajdabiya',
#   'Country': 'LY',
#   'Lat': 30.7554,
#   'Lng': 20.2263,
#   'Max Temp': 69.89,
#   'Humidity': 72,
#   'Cloudiness': 33,
#   'Wind Speed': 8.68,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Guarapari',
#   'Country': 'BR',
#   'Lat': -20.6667,
#   'Lng': -40.4975,
#   'Max Temp': 71.49,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 9.28,
#   'Current Description': 'moderate rain'},
#  {'City': 'Ulaangom',
#   'Country': 'MN',
#   'Lat': 49.9811,
#   'Lng': 92.0667,
#   'Max Temp': 34.52,
#   'Humidity': 51,
#   'Cloudiness': 100,
#   'Wind Speed': 3.56,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint-Marc',
#   'Country': 'HT',
#   'Lat': 19.1082,
#   'Lng': -72.6938,
#   'Max Temp': 85.68,
#   'Humidity': 57,
#   'Cloudiness': 71,
#   'Wind Speed': 6.15,
#   'Current Description': 'broken clouds'},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 56.52,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 15.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Santa Cruz de la Sierra',
#   'Country': 'BO',
#   'Lat': -17.8,
#   'Lng': -63.1667,
#   'Max Temp': 94.46,
#   'Humidity': 55,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Current Description': 'light rain'},
#  {'City': 'La Venta del Astillero',
#   'Country': 'MX',
#   'Lat': 20.7167,
#   'Lng': -103.5333,
#   'Max Temp': 78.1,
#   'Humidity': 39,
#   'Cloudiness': 5,
#   'Wind Speed': 3.33,
#   'Current Description': 'clear sky'},
#  {'City': 'Mananjary',
#   'Country': 'MG',
#   'Lat': -21.2167,
#   'Lng': 48.3333,
#   'Max Temp': 73.04,
#   'Humidity': 92,
#   'Cloudiness': 96,
#   'Wind Speed': 7.83,
#   'Current Description': 'light rain'},
#  {'City': 'George Town',
#   'Country': 'MY',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 79.9,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 3,
#   'Current Description': 'few clouds'},
#  {'City': 'Begunitsy',
#   'Country': 'RU',
#   'Lat': 59.5855,
#   'Lng': 29.3176,
#   'Max Temp': 43.38,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 8.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bengkulu',
#   'Country': 'ID',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 76.53,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 4.36,
#   'Current Description': 'light rain'},
#  {'City': 'Chara',
#   'Country': 'RU',
#   'Lat': 56.9064,
#   'Lng': 118.2631,
#   'Max Temp': 21.58,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 0.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gympie',
#   'Country': 'AU',
#   'Lat': -26.1898,
#   'Lng': 152.665,
#   'Max Temp': 66.02,
#   'Humidity': 81,
#   'Cloudiness': 93,
#   'Wind Speed': 3.65,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 61.12,
#   'Humidity': 94,
#   'Cloudiness': 99,
#   'Wind Speed': 6.35,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chapais',
#   'Country': 'CA',
#   'Lat': 49.7834,
#   'Lng': -74.8492,
#   'Max Temp': 42.58,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 5.3,
#   'Current Description': 'light rain'},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 7.09,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 11.56,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 32.74,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 23.33,
#   'Current Description': 'snow'},
#  {'City': 'Pankovka',
#   'Country': 'RU',
#   'Lat': 58.5,
#   'Lng': 31.1999,
#   'Max Temp': 44.33,
#   'Humidity': 86,
#   'Cloudiness': 39,
#   'Wind Speed': 8.75,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 72.1,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Current Description': 'clear sky'},
#  {'City': 'Saint-Pierre',
#   'Country': 'RE',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 71.28,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Alekseyevka',
#   'Country': 'RU',
#   'Lat': 50.6309,
#   'Lng': 38.6903,
#   'Max Temp': 42.87,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 5.53,
#   'Current Description': 'clear sky'},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 81.28,
#   'Humidity': 77,
#   'Cloudiness': 44,
#   'Wind Speed': 9.78,
#   'Current Description': 'light rain'},
#  {'City': 'Mayo',
#   'Country': 'US',
#   'Lat': 38.8876,
#   'Lng': -76.5119,
#   'Max Temp': 68.41,
#   'Humidity': 61,
#   'Cloudiness': 90,
#   'Wind Speed': 7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bataiporã',
#   'Country': 'BR',
#   'Lat': -22.2953,
#   'Lng': -53.2711,
#   'Max Temp': 76.05,
#   'Humidity': 73,
#   'Cloudiness': 78,
#   'Wind Speed': 7.78,
#   'Current Description': 'broken clouds'},
#  {'City': 'Orange Cove',
#   'Country': 'US',
#   'Lat': 36.6244,
#   'Lng': -119.3137,
#   'Max Temp': 70.63,
#   'Humidity': 59,
#   'Cloudiness': 58,
#   'Wind Speed': 4.52,
#   'Current Description': 'broken clouds'},
#  {'City': 'Darasun',
#   'Country': 'RU',
#   'Lat': 51.6667,
#   'Lng': 114,
#   'Max Temp': 12.74,
#   'Humidity': 63,
#   'Cloudiness': 11,
#   'Wind Speed': 1.86,
#   'Current Description': 'few clouds'},
#  {'City': 'Kostanay',
#   'Country': 'KZ',
#   'Lat': 53.1667,
#   'Lng': 63.5833,
#   'Max Temp': 44.58,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 12.8,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Harrison',
#   'Country': 'US',
#   'Lat': 30.4091,
#   'Lng': -89.0436,
#   'Max Temp': 73.76,
#   'Humidity': 60,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Sayyan',
#   'Country': 'YE',
#   'Lat': 15.1718,
#   'Lng': 44.3244,
#   'Max Temp': 55.98,
#   'Humidity': 56,
#   'Cloudiness': 60,
#   'Wind Speed': 10.47,
#   'Current Description': 'broken clouds'},
#  {'City': 'Rognan',
#   'Country': 'NO',
#   'Lat': 67.0953,
#   'Lng': 15.3878,
#   'Max Temp': 47.88,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 8.01,
#   'Current Description': 'light rain'},
#  {'City': 'Lashio',
#   'Country': 'MM',
#   'Lat': 22.9333,
#   'Lng': 97.75,
#   'Max Temp': 61.7,
#   'Humidity': 99,
#   'Cloudiness': 20,
#   'Wind Speed': 1.03,
#   'Current Description': 'few clouds'},
#  {'City': 'Kumul',
#   'Country': 'CN',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 49.57,
#   'Humidity': 46,
#   'Cloudiness': 100,
#   'Wind Speed': 3.87,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -10.16,
#   'Humidity': 100,
#   'Cloudiness': 99,
#   'Wind Speed': 5.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Fairbanks',
#   'Country': 'US',
#   'Lat': 64.8378,
#   'Lng': -147.7164,
#   'Max Temp': 46.36,
#   'Humidity': 47,
#   'Cloudiness': 20,
#   'Wind Speed': 14.97,
#   'Current Description': 'few clouds'},
#  {'City': 'Souillac',
#   'Country': 'MU',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 72.36,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Current Description': 'broken clouds'},
#  {'City': 'Yamada',
#   'Country': 'JP',
#   'Lat': 39.4667,
#   'Lng': 141.95,
#   'Max Temp': 51.73,
#   'Humidity': 82,
#   'Cloudiness': 14,
#   'Wind Speed': 4.63,
#   'Current Description': 'few clouds'},
#  {'City': 'Aloleng',
#   'Country': 'PH',
#   'Lat': 16.1307,
#   'Lng': 119.7824,
#   'Max Temp': 77.85,
#   'Humidity': 74,
#   'Cloudiness': 17,
#   'Wind Speed': 8.68,
#   'Current Description': 'few clouds'},
#  {'City': 'Arraial do Cabo',
#   'Country': 'BR',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 73.36,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Current Description': 'mist'},
#  {'City': 'Saint Paul Harbor',
#   'Country': 'US',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 44.11,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Current Description': 'light rain'},
#  {'City': 'Kaifeng',
#   'Country': 'CN',
#   'Lat': 34.7911,
#   'Lng': 114.3483,
#   'Max Temp': 58.06,
#   'Humidity': 73,
#   'Cloudiness': 97,
#   'Wind Speed': 10.4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Biltine',
#   'Country': 'TD',
#   'Lat': 14.5333,
#   'Lng': 20.9167,
#   'Max Temp': 86.81,
#   'Humidity': 17,
#   'Cloudiness': 38,
#   'Wind Speed': 7.2,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Esim',
#   'Country': 'GH',
#   'Lat': 4.8699,
#   'Lng': -2.2405,
#   'Max Temp': 78.17,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 8.63,
#   'Current Description': 'moderate rain'},
#  {'City': 'Nerchinskiy Zavod',
#   'Country': 'RU',
#   'Lat': 51.3088,
#   'Lng': 119.61,
#   'Max Temp': 22.23,
#   'Humidity': 53,
#   'Cloudiness': 76,
#   'Wind Speed': 5.59,
#   'Current Description': 'broken clouds'},
#  {'City': 'Solnechnyy',
#   'Country': 'RU',
#   'Lat': 50.7214,
#   'Lng': 136.6319,
#   'Max Temp': 23.99,
#   'Humidity': 67,
#   'Cloudiness': 1,
#   'Wind Speed': 1.66,
#   'Current Description': 'clear sky'},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 68.4,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mlonggo',
#   'Country': 'ID',
#   'Lat': -6.5333,
#   'Lng': 110.7,
#   'Max Temp': 76.51,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 3.58,
#   'Current Description': 'moderate rain'},
#  {'City': 'Caravelas',
#   'Country': 'BR',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 77.43,
#   'Humidity': 75,
#   'Cloudiness': 90,
#   'Wind Speed': 8.81,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Altamont',
#   'Country': 'US',
#   'Lat': 42.2068,
#   'Lng': -121.7372,
#   'Max Temp': 55.78,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 3,
#   'Current Description': 'broken clouds'},
#  {'City': 'The Pas',
#   'Country': 'CA',
#   'Lat': 53.8251,
#   'Lng': -101.2541,
#   'Max Temp': 35.62,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 12.66,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Aklavik',
#   'Country': 'CA',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': 34.63,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Current Description': 'broken clouds'},
#  {'City': 'Adrar',
#   'Country': 'MR',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 87.67,
#   'Humidity': 13,
#   'Cloudiness': 100,
#   'Wind Speed': 9.98,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hinganghāt',
#   'Country': 'IN',
#   'Lat': 20.5667,
#   'Lng': 78.8333,
#   'Max Temp': 67.41,
#   'Humidity': 56,
#   'Cloudiness': 9,
#   'Wind Speed': 5.41,
#   'Current Description': 'clear sky'},
#  {'City': 'La Troncal',
#   'Country': 'EC',
#   'Lat': -2.4,
#   'Lng': -79.3333,
#   'Max Temp': 90.72,
#   'Humidity': 62,
#   'Cloudiness': 96,
#   'Wind Speed': 1.1,
#   'Current Description': 'light rain'},
#  {'City': 'Shelburne',
#   'Country': 'CA',
#   'Lat': 44.0787,
#   'Lng': -80.2041,
#   'Max Temp': 56.12,
#   'Humidity': 73,
#   'Cloudiness': 5,
#   'Wind Speed': 16.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Odesa',
#   'Country': 'UA',
#   'Lat': 46.4775,
#   'Lng': 30.7326,
#   'Max Temp': 39.13,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Current Description': 'fog'},
#  {'City': 'Orlik',
#   'Country': 'RU',
#   'Lat': 52.5178,
#   'Lng': 99.825,
#   'Max Temp': 25.21,
#   'Humidity': 71,
#   'Cloudiness': 65,
#   'Wind Speed': 4.41,
#   'Current Description': 'broken clouds'},
#  {'City': 'Olafsvik',
#   'Country': 'IS',
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp': 35.44,
#   'Humidity': 70,
#   'Cloudiness': 39,
#   'Wind Speed': 17.2,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kālāvad',
#   'Country': 'IN',
#   'Lat': 22.2167,
#   'Lng': 70.3833,
#   'Max Temp': 74.88,
#   'Humidity': 29,
#   'Cloudiness': 5,
#   'Wind Speed': 5.28,
#   'Current Description': 'clear sky'},
#  {'City': 'Harper',
#   'Country': 'LR',
#   'Lat': 4.375,
#   'Lng': -7.7169,
#   'Max Temp': 77.83,
#   'Humidity': 86,
#   'Cloudiness': 53,
#   'Wind Speed': 9.37,
#   'Current Description': 'light rain'},
#  {'City': 'Narón',
#   'Country': 'ES',
#   'Lat': 43.5167,
#   'Lng': -8.1528,
#   'Max Temp': 60.67,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 14.88,
#   'Current Description': 'overcast clouds'},
#  {'City': 'São Filipe',
#   'Country': 'CV',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 79.68,
#   'Humidity': 75,
#   'Cloudiness': 99,
#   'Wind Speed': 11.43,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Talcahuano',
#   'Country': 'CL',
#   'Lat': -36.7167,
#   'Lng': -73.1167,
#   'Max Temp': 62.28,
#   'Humidity': 67,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kenora',
#   'Country': 'CA',
#   'Lat': 49.8167,
#   'Lng': -94.4337,
#   'Max Temp': 38.59,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Current Description': 'broken clouds'},
#  {'City': 'Clyde River',
#   'Country': 'CA',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 21.43,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Current Description': 'light snow'},
#  {'City': 'Montemor-o-Novo',
#   'Country': 'PT',
#   'Lat': 38.6481,
#   'Lng': -8.2145,
#   'Max Temp': 67.41,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 11.3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Said',
#   'Country': 'EG',
#   'Lat': 31.2565,
#   'Lng': 32.2841,
#   'Max Temp': 76.98,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Codrington',
#   'Country': 'AU',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 43.7,
#   'Humidity': 93,
#   'Cloudiness': 9,
#   'Wind Speed': 5.06,
#   'Current Description': 'clear sky'},
#  {'City': 'Howard Springs',
#   'Country': 'AU',
#   'Lat': -12.497,
#   'Lng': 131.047,
#   'Max Temp': 78.71,
#   'Humidity': 86,
#   'Cloudiness': 11,
#   'Wind Speed': 5.79,
#   'Current Description': 'few clouds'},
#  {'City': 'Vostok',
#   'Country': 'RU',
#   'Lat': 46.4856,
#   'Lng': 135.8833,
#   'Max Temp': 26.62,
#   'Humidity': 94,
#   'Cloudiness': 16,
#   'Wind Speed': 1.41,
#   'Current Description': 'few clouds'},
#  {'City': 'Severnoye',
#   'Country': 'RU',
#   'Lat': 56.3491,
#   'Lng': 78.3619,
#   'Max Temp': 18.1,
#   'Humidity': 94,
#   'Cloudiness': 49,
#   'Wind Speed': 6.51,
#   'Current Description': 'scattered clouds'},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 54.91,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Longyearbyen',
#   'Country': 'SJ',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 30.04,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Lata',
#   'Country': 'PT',
#   'Lat': 40.1629,
#   'Lng': -8.3327,
#   'Max Temp': 67.93,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 5.55,
#   'Current Description': 'light rain'},
#  {'City': 'Hong Kong',
#   'Country': 'HK',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 76.32,
#   'Humidity': 82,
#   'Cloudiness': 85,
#   'Wind Speed': 1.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ancud',
#   'Country': 'CL',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 72.93,
#   'Humidity': 56,
#   'Cloudiness': 42,
#   'Wind Speed': 8.19,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Whyalla',
#   'Country': 'AU',
#   'Lat': -33.0333,
#   'Lng': 137.5833,
#   'Max Temp': 49.89,
#   'Humidity': 71,
#   'Cloudiness': 97,
#   'Wind Speed': 3.44,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Camaquã',
#   'Country': 'BR',
#   'Lat': -30.8511,
#   'Lng': -51.8122,
#   'Max Temp': 76.93,
#   'Humidity': 66,
#   'Cloudiness': 19,
#   'Wind Speed': 10.2,
#   'Current Description': 'few clouds'},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 12.2,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 8.28,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Galesong',
#   'Country': 'ID',
#   'Lat': -5.3166,
#   'Lng': 119.3661,
#   'Max Temp': 75.22,
#   'Humidity': 82,
#   'Cloudiness': 99,
#   'Wind Speed': 3.58,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Palana',
#   'Country': 'RU',
#   'Lat': 59.1167,
#   'Lng': 159.9667,
#   'Max Temp': 12.78,
#   'Humidity': 72,
#   'Cloudiness': 70,
#   'Wind Speed': 20.22,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nuuk',
#   'Country': 'GL',
#   'Lat': 64.1835,
#   'Lng': -51.7216,
#   'Max Temp': 38.01,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 21.85,
#   'Current Description': 'light rain'},
#  {'City': 'Faanui',
#   'Country': 'PF',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 78.57,
#   'Humidity': 70,
#   'Cloudiness': 99,
#   'Wind Speed': 15.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tiksi',
#   'Country': 'RU',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 17.87,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 16.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Huejuquilla el Alto',
#   'Country': 'MX',
#   'Lat': 22.6,
#   'Lng': -103.8667,
#   'Max Temp': 76.03,
#   'Humidity': 31,
#   'Cloudiness': 1,
#   'Wind Speed': 3.74,
#   'Current Description': 'clear sky'},
#  {'City': 'Richards Bay',
#   'Country': 'ZA',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 65.08,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 4.83,
#   'Current Description': 'clear sky'},
#  {'City': 'Zaysan',
#   'Country': 'KZ',
#   'Lat': 47.4667,
#   'Lng': 84.8667,
#   'Max Temp': 39.22,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 7.29,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 26.6,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bethel',
#   'Country': 'US',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 64.99,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 1.01,
#   'Current Description': 'broken clouds'},
#  {'City': 'Klaksvík',
#   'Country': 'FO',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 40.12,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 2.91,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mineiros',
#   'Country': 'BR',
#   'Lat': -17.5694,
#   'Lng': -52.5511,
#   'Max Temp': 69.01,
#   'Humidity': 89,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Neiafu',
#   'Country': 'TO',
#   'Lat': -18.65,
#   'Lng': -173.9833,
#   'Max Temp': 77.68,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Khilok',
#   'Country': 'RU',
#   'Lat': 51.3674,
#   'Lng': 110.4676,
#   'Max Temp': 28.18,
#   'Humidity': 71,
#   'Cloudiness': 76,
#   'Wind Speed': 4.32,
#   'Current Description': 'broken clouds'},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 68.07,
#   'Humidity': 68,
#   'Cloudiness': 90,
#   'Wind Speed': 18.41,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Maragogi',
#   'Country': 'BR',
#   'Lat': -9.0122,
#   'Lng': -35.2225,
#   'Max Temp': 78.89,
#   'Humidity': 72,
#   'Cloudiness': 22,
#   'Wind Speed': 7.9,
#   'Current Description': 'few clouds'},
#  {'City': 'Mount Gambier',
#   'Country': 'AU',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 44.51,
#   'Humidity': 100,
#   'Cloudiness': 10,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Rocha',
#   'Country': 'UY',
#   'Lat': -34.4833,
#   'Lng': -54.3333,
#   'Max Temp': 71.37,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 7.36,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Forsytheganj',
#   'Country': 'BY',
#   'Lat': 52.6333,
#   'Lng': 29.7333,
#   'Max Temp': 41.63,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 7.65,
#   'Current Description': 'clear sky'},
#  {'City': 'Mt. Pleasant',
#   'Country': 'US',
#   'Lat': 32.7941,
#   'Lng': -79.8626,
#   'Max Temp': 73.31,
#   'Humidity': 59,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Current Description': 'clear sky'},
#  {'City': 'Barysh',
#   'Country': 'RU',
#   'Lat': 53.6553,
#   'Lng': 47.1123,
#   'Max Temp': 44.42,
#   'Humidity': 76,
#   'Cloudiness': 12,
#   'Wind Speed': 11.43,
#   'Current Description': 'few clouds'},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 32.41,
#   'Humidity': 99,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01,
#   'Current Description': 'light snow'},
#  {'City': 'Angoche',
#   'Country': 'MZ',
#   'Lat': -16.2325,
#   'Lng': 39.9086,
#   'Max Temp': 77.81,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 13.11,
#   'Current Description': 'clear sky'},
#  {'City': 'Vao',
#   'Country': 'NC',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 71.2,
#   'Humidity': 64,
#   'Cloudiness': 12,
#   'Wind Speed': 9.26,
#   'Current Description': 'few clouds'},
#  {'City': 'Yerofey Pavlovich',
#   'Country': 'RU',
#   'Lat': 53.9667,
#   'Lng': 121.9667,
#   'Max Temp': 24.01,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 0.89,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nortelândia',
#   'Country': 'BR',
#   'Lat': -14.4547,
#   'Lng': -56.8028,
#   'Max Temp': 80.47,
#   'Humidity': 73,
#   'Cloudiness': 97,
#   'Wind Speed': 5.57,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Berbera',
#   'Country': 'SO',
#   'Lat': 10.4396,
#   'Lng': 45.0143,
#   'Max Temp': 83.61,
#   'Humidity': 64,
#   'Cloudiness': 31,
#   'Wind Speed': 8.21,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sergeevka',
#   'Country': 'KZ',
#   'Lat': 53.88,
#   'Lng': 67.4158,
#   'Max Temp': 37.62,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 11.65,
#   'Current Description': 'light rain'},
#  {'City': 'Kanbe',
#   'Country': 'MM',
#   'Lat': 16.7053,
#   'Lng': 96.0017,
#   'Max Temp': 80.65,
#   'Humidity': 93,
#   'Cloudiness': 86,
#   'Wind Speed': 3.04,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yar-Sale',
#   'Country': 'RU',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Max Temp': 2.71,
#   'Humidity': 93,
#   'Cloudiness': 77,
#   'Wind Speed': 4.88,
#   'Current Description': 'broken clouds'},
#  {'City': 'Srednekolymsk',
#   'Country': 'RU',
#   'Lat': 67.45,
#   'Lng': 153.6833,
#   'Max Temp': -6.41,
#   'Humidity': 99,
#   'Cloudiness': 99,
#   'Wind Speed': 6.85,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Matsubase',
#   'Country': 'JP',
#   'Lat': 32.65,
#   'Lng': 130.6667,
#   'Max Temp': 64.18,
#   'Humidity': 80,
#   'Cloudiness': 70,
#   'Wind Speed': 3.4,
#   'Current Description': 'broken clouds'},
#  {'City': 'Socorro',
#   'Country': 'US',
#   'Lat': 31.6546,
#   'Lng': -106.3033,
#   'Max Temp': 79.92,
#   'Humidity': 20,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mitú',
#   'Country': 'CO',
#   'Lat': 1.1983,
#   'Lng': -70.1733,
#   'Max Temp': 78.46,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 1.77,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tooele',
#   'Country': 'US',
#   'Lat': 40.5308,
#   'Lng': -112.2983,
#   'Max Temp': 67.24,
#   'Humidity': 67,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Current Description': 'scattered clouds'},
#  {'City': 'San Patricio',
#   'Country': 'US',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 88.21,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 12.8,
#   'Current Description': 'clear sky'},
#  {'City': 'La Santisima Trinidad',
#   'Country': 'BO',
#   'Lat': -14.8333,
#   'Lng': -64.9,
#   'Max Temp': 98.58,
#   'Humidity': 41,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Current Description': 'few clouds'},
#  {'City': 'Cairns',
#   'Country': 'AU',
#   'Lat': -16.9167,
#   'Lng': 145.7667,
#   'Max Temp': 78.75,
#   'Humidity': 91,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Portland',
#   'Country': 'US',
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 62.51,
#   'Humidity': 41,
#   'Cloudiness': 20,
#   'Wind Speed': 1.99,
#   'Current Description': 'few clouds'},
#  {'City': 'Payo',
#   'Country': 'ID',
#   'Lat': -3.7508,
#   'Lng': 103.6372,
#   'Max Temp': 73.17,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.59,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kudahuvadhoo',
#   'Country': 'MV',
#   'Lat': 2.6708,
#   'Lng': 72.8944,
#   'Max Temp': 82.49,
#   'Humidity': 77,
#   'Cloudiness': 35,
#   'Wind Speed': 19.08,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sterling',
#   'Country': 'US',
#   'Lat': 39.0062,
#   'Lng': -77.4286,
#   'Max Temp': 67.44,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 1.01,
#   'Current Description': 'broken clouds'},
#  {'City': 'Saint George',
#   'Country': 'US',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 81.07,
#   'Humidity': 32,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Current Description': 'clear sky'},
#  {'City': 'Te Anau',
#   'Country': 'NZ',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 47.44,
#   'Humidity': 71,
#   'Cloudiness': 65,
#   'Wind Speed': 2.68,
#   'Current Description': 'broken clouds'},
#  {'City': 'Half Moon Bay',
#   'Country': 'US',
#   'Lat': 37.4636,
#   'Lng': -122.4286,
#   'Max Temp': 67.24,
#   'Humidity': 71,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hofn',
#   'Country': 'IS',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 39.49,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 20.45,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rawson',
#   'Country': 'AR',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 51.48,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 12.19,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Petropavlovka',
#   'Country': 'RU',
#   'Lat': 50.6114,
#   'Lng': 105.3196,
#   'Max Temp': 31.75,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 1.9,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bathsheba',
#   'Country': 'BB',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 84.81,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Cayenne',
#   'Country': 'GF',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 86.04,
#   'Humidity': 76,
#   'Cloudiness': 93,
#   'Wind Speed': 7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dholka',
#   'Country': 'IN',
#   'Lat': 22.7167,
#   'Lng': 72.4667,
#   'Max Temp': 66.58,
#   'Humidity': 32,
#   'Cloudiness': 2,
#   'Wind Speed': 6.58,
#   'Current Description': 'clear sky'},
#  {'City': 'Yuxia',
#   'Country': 'CN',
#   'Lat': 34.0615,
#   'Lng': 108.6291,
#   'Max Temp': 47.01,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 2.51,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Myskhako',
#   'Country': 'RU',
#   'Lat': 44.6714,
#   'Lng': 37.7433,
#   'Max Temp': 51.58,
#   'Humidity': 60,
#   'Cloudiness': 98,
#   'Wind Speed': 4.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tiarei',
#   'Country': 'PF',
#   'Lat': -17.5333,
#   'Lng': -149.3333,
#   'Max Temp': 82.42,
#   'Humidity': 73,
#   'Cloudiness': 67,
#   'Wind Speed': 14.9,
#   'Current Description': 'broken clouds'},
#  {'City': 'Laguna',
#   'Country': 'US',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 67.98,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 1.01,
#   'Current Description': 'broken clouds'},
#  {'City': 'Darnah',
#   'Country': 'LY',
#   'Lat': 32.767,
#   'Lng': 22.6367,
#   'Max Temp': 67.44,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 19.33,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Airai',
#   'Country': 'TL',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 60.08,
#   'Humidity': 84,
#   'Cloudiness': 76,
#   'Wind Speed': 1.66,
#   'Current Description': 'broken clouds'},
#  {'City': 'Yangi Marg`ilon',
#   'Country': 'UZ',
#   'Lat': 40.4272,
#   'Lng': 71.7189,
#   'Max Temp': 45.82,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 9.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Ponta do Sol',
#   'Country': 'PT',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 75,
#   'Humidity': 82,
#   'Cloudiness': 59,
#   'Wind Speed': 7.02,
#   'Current Description': 'broken clouds'},
#  {'City': "Kem'",
#   'Country': 'RU',
#   'Lat': 64.9555,
#   'Lng': 34.5793,
#   'Max Temp': 41.13,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 6.08,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Alekseyevsk',
#   'Country': 'RU',
#   'Lat': 57.8406,
#   'Lng': 108.3492,
#   'Max Temp': 32.11,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kurchum',
#   'Country': 'KZ',
#   'Lat': 48.5722,
#   'Lng': 83.6542,
#   'Max Temp': 37.96,
#   'Humidity': 76,
#   'Cloudiness': 85,
#   'Wind Speed': 17.47,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Buta',
#   'Country': 'CD',
#   'Lat': 2.7858,
#   'Lng': 24.73,
#   'Max Temp': 67.82,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 3.78,
#   'Current Description': 'light rain'},
#  {'City': 'Oranjemund',
#   'Country': 'NA',
#   'Lat': -28.55,
#   'Lng': 16.4333,
#   'Max Temp': 63.19,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 8.1,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Manokwari',
#   'Country': 'ID',
#   'Lat': -0.8667,
#   'Lng': 134.0833,
#   'Max Temp': 78.53,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 5.73,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 69.39,
#   'Humidity': 85,
#   'Cloudiness': 30,
#   'Wind Speed': 8.99,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Samarai',
#   'Country': 'PG',
#   'Lat': -10.6167,
#   'Lng': 150.6667,
#   'Max Temp': 82.45,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 16.02,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dongying',
#   'Country': 'CN',
#   'Lat': 37.4564,
#   'Lng': 118.4856,
#   'Max Temp': 52.23,
#   'Humidity': 64,
#   'Cloudiness': 47,
#   'Wind Speed': 6.55,
#   'Current Description': 'light rain'},
#  {'City': 'Nouadhibou',
#   'Country': 'MR',
#   'Lat': 20.931,
#   'Lng': -17.0347,
#   'Max Temp': 73.38,
#   'Humidity': 68,
#   'Cloudiness': 2,
#   'Wind Speed': 11.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Coquimbo',
#   'Country': 'CL',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 62.33,
#   'Humidity': 72,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Antalaha',
#   'Country': 'MG',
#   'Lat': -14.9003,
#   'Lng': 50.2788,
#   'Max Temp': 72.39,
#   'Humidity': 91,
#   'Cloudiness': 9,
#   'Wind Speed': 3.58,
#   'Current Description': 'light rain'},
#  {'City': 'Omsukchan',
#   'Country': 'RU',
#   'Lat': 62.5333,
#   'Lng': 155.8,
#   'Max Temp': -14.62,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4.97,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Zhigansk',
#   'Country': 'RU',
#   'Lat': 66.7697,
#   'Lng': 123.3711,
#   'Max Temp': 4.14,
#   'Humidity': 94,
#   'Cloudiness': 74,
#   'Wind Speed': 11.63,
#   'Current Description': 'broken clouds'},
#  {'City': 'Alamogordo',
#   'Country': 'US',
#   'Lat': 32.8995,
#   'Lng': -105.9603,
#   'Max Temp': 77.97,
#   'Humidity': 22,
#   'Cloudiness': 1,
#   'Wind Speed': 4,
#   'Current Description': 'clear sky'},
#  {'City': 'Lukang',
#   'Country': 'TW',
#   'Lat': 24.0567,
#   'Lng': 120.4352,
#   'Max Temp': 77.43,
#   'Humidity': 84,
#   'Cloudiness': 7,
#   'Wind Speed': 8.41,
#   'Current Description': 'clear sky'},
#  {'City': 'Vardø',
#   'Country': 'NO',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 35.58,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mehamn',
#   'Country': 'NO',
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp': 35.78,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Abilene',
#   'Country': 'US',
#   'Lat': 32.4487,
#   'Lng': -99.7331,
#   'Max Temp': 75.33,
#   'Humidity': 37,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Tutóia',
#   'Country': 'BR',
#   'Lat': -2.7619,
#   'Lng': -42.2744,
#   'Max Temp': 87.78,
#   'Humidity': 75,
#   'Cloudiness': 18,
#   'Wind Speed': 11.14,
#   'Current Description': 'few clouds'},
#  {'City': 'Suşehri',
#   'Country': 'TR',
#   'Lat': 40.1644,
#   'Lng': 38.0867,
#   'Max Temp': 51.06,
#   'Humidity': 83,
#   'Cloudiness': 55,
#   'Wind Speed': 4.43,
#   'Current Description': 'broken clouds'},
#  {'City': 'Diamantino',
#   'Country': 'BR',
#   'Lat': -14.4086,
#   'Lng': -56.4461,
#   'Max Temp': 80.85,
#   'Humidity': 70,
#   'Cloudiness': 83,
#   'Wind Speed': 6.53,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Cabedelo',
#   'Country': 'BR',
#   'Lat': -6.9811,
#   'Lng': -34.8339,
#   'Max Temp': 84.87,
#   'Humidity': 71,
#   'Cloudiness': 70,
#   'Wind Speed': 14.88,
#   'Current Description': 'broken clouds'},
#  {'City': "Parabel'",
#   'Country': 'RU',
#   'Lat': 58.6978,
#   'Lng': 81.4825,
#   'Max Temp': 13.6,
#   'Humidity': 83,
#   'Cloudiness': 60,
#   'Wind Speed': 10.96,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 47.01,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 8.46,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Macquarie',
#   'Country': 'AU',
#   'Lat': -31.4333,
#   'Lng': 152.9167,
#   'Max Temp': 57.88,
#   'Humidity': 77,
#   'Cloudiness': 59,
#   'Wind Speed': 4.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mar del Plata',
#   'Country': 'AR',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 59.09,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 1.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cherskiy',
#   'Country': 'RU',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': -1.68,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 4.92,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Erenhot',
#   'Country': 'CN',
#   'Lat': 43.6475,
#   'Lng': 111.9767,
#   'Max Temp': 33.42,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 5.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Alofi',
#   'Country': 'NU',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 76.89,
#   'Humidity': 78,
#   'Cloudiness': 34,
#   'Wind Speed': 9.22,
#   'Current Description': 'light rain'},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 33.96,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Current Description': 'broken clouds'},
#  {'City': 'La Unión',
#   'Country': 'PE',
#   'Lat': -5.4,
#   'Lng': -80.75,
#   'Max Temp': 79.66,
#   'Humidity': 45,
#   'Cloudiness': 17,
#   'Wind Speed': 16.82,
#   'Current Description': 'few clouds'},
#  {'City': "Severo-Kuril'sk",
#   'Country': 'RU',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 34.7,
#   'Humidity': 62,
#   'Cloudiness': 99,
#   'Wind Speed': 27.74,
#   'Current Description': 'light rain'},
#  {'City': 'Wasilla',
#   'Country': 'US',
#   'Lat': 61.5814,
#   'Lng': -149.4394,
#   'Max Temp': 46.02,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 7,
#   'Current Description': 'light rain'},
#  {'City': 'Rena',
#   'Country': 'NO',
#   'Lat': 61.1348,
#   'Lng': 11.3641,
#   'Max Temp': 41.83,
#   'Humidity': 99,
#   'Cloudiness': 92,
#   'Wind Speed': 3.56,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Hardy',
#   'Country': 'CA',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 48.38,
#   'Humidity': 57,
#   'Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Kahului',
#   'Country': 'US',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 87.06,
#   'Humidity': 62,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Vila Franca do Campo',
#   'Country': 'PT',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 71.2,
# ...
#   'Lat': 7.4167,
#   'Lng': 81.8167,
#   'Max Temp': 78.58,
#   'Humidity': 87,
#   'Cloudiness': 59,
#   'Wind Speed': 6.98,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bulgan',
#   'Country': 'MN',
#   'Lat': 48.8125,
#   'Lng': 103.5347,
#   'Max Temp': 31.62,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind Speed': 2.44,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Beirut',
#   'Country': 'LB',
#   'Lat': 33.8889,
#   'Lng': 35.4944,
#   'Max Temp': 76.86,
#   'Humidity': 44,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Current Description': 'few clouds'},
#  {'City': 'Sumbe',
#   'Country': 'AO',
#   'Lat': -11.2061,
#   'Lng': 13.8437,
#   'Max Temp': 74.71,
#   'Humidity': 83,
#   'Cloudiness': 27,
#   'Wind Speed': 9.15,
#   'Current Description': 'light rain'},
#  {'City': 'Ilo',
#   'Country': 'PE',
#   'Lat': -17.6394,
#   'Lng': -71.3375,
#   'Max Temp': 66.06,
#   'Humidity': 74,
#   'Cloudiness': 89,
#   'Wind Speed': 6.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Alyangula',
#   'Country': 'AU',
#   'Lat': -13.8483,
#   'Lng': 136.4192,
#   'Max Temp': 76.87,
#   'Humidity': 100,
#   'Cloudiness': 51,
#   'Wind Speed': 0,
#   'Current Description': 'broken clouds'},
#  {'City': 'Fuxin',
#   'Country': 'CN',
#   'Lat': 42.0156,
#   'Lng': 121.6589,
#   'Max Temp': 34.02,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 4.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Kismayo',
#   'Country': 'SO',
#   'Lat': -0.3582,
#   'Lng': 42.5454,
#   'Max Temp': 78.57,
#   'Humidity': 85,
#   'Cloudiness': 15,
#   'Wind Speed': 13.44,
#   'Current Description': 'few clouds'},
#  {'City': 'Haveli Lakha',
#   'Country': 'PK',
#   'Lat': 30.4502,
#   'Lng': 73.6989,
#   'Max Temp': 69.33,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 7.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Egvekinot',
#   'Country': 'RU',
#   'Lat': 66.3167,
#   'Lng': -179.1667,
#   'Max Temp': -1.68,
#   'Humidity': 86,
#   'Cloudiness': 98,
#   'Wind Speed': 9.98,
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Miguel de Tucumán',
#   'Country': 'AR',
#   'Lat': -26.8241,
#   'Lng': -65.2226,
#   'Max Temp': 80.6,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Current Description': 'broken clouds'},
#  {'City': 'Dingcheng',
#   'Country': 'CN',
#   'Lat': 32.1272,
#   'Lng': 115.0394,
#   'Max Temp': 60.06,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 6.6,
#   'Current Description': 'light rain'},
#  {'City': 'Los Llanos de Aridane',
#   'Country': 'ES',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 67.75,
#   'Humidity': 85,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Rexburg',
#   'Country': 'US',
#   'Lat': 43.826,
#   'Lng': -111.7897,
#   'Max Temp': 58.26,
#   'Humidity': 47,
#   'Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Kodinsk',
#   'Country': 'RU',
#   'Lat': 58.6881,
#   'Lng': 99.1844,
#   'Max Temp': 29.08,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 4.97,
#   'Current Description': 'light snow'},
#  {'City': 'La Macarena',
#   'Country': 'CO',
#   'Lat': 2.1837,
#   'Lng': -73.7849,
#   'Max Temp': 80.49,
#   'Humidity': 86,
#   'Cloudiness': 97,
#   'Wind Speed': 2.44,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Bohmte',
#   'Country': 'DE',
#   'Lat': 52.3667,
#   'Lng': 8.3167,
#   'Max Temp': 62.89,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 23.42,
#   'Current Description': 'moderate rain'},
#  {'City': 'Catuday',
#   'Country': 'PH',
#   'Lat': 16.2923,
#   'Lng': 119.8062,
#   'Max Temp': 77.45,
#   'Humidity': 75,
#   'Cloudiness': 32,
#   'Wind Speed': 10.22,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Feijó',
#   'Country': 'BR',
#   'Lat': -8.1642,
#   'Lng': -70.3536,
#   'Max Temp': 90.64,
#   'Humidity': 48,
#   'Cloudiness': 100,
#   'Wind Speed': 3.53,
#   'Current Description': 'light rain'},
#  {'City': 'Örnsköldsvik',
#   'Country': 'SE',
#   'Lat': 63.2909,
#   'Lng': 18.7153,
#   'Max Temp': 43.75,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Current Description': 'mist'},
#  {'City': 'Binka',
#   'Country': 'IN',
#   'Lat': 21.0333,
#   'Lng': 83.8,
#   'Max Temp': 71.13,
#   'Humidity': 73,
#   'Cloudiness': 8,
#   'Wind Speed': 2.93,
#   'Current Description': 'clear sky'},
#  {'City': 'Omboué',
#   'Country': 'GA',
#   'Lat': -1.5746,
#   'Lng': 9.2618,
#   'Max Temp': 76.24,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 7.56,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Aljezur',
#   'Country': 'PT',
#   'Lat': 37.3191,
#   'Lng': -8.8033,
#   'Max Temp': 68.05,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 10.09,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Along',
#   'Country': 'IN',
#   'Lat': 28.1667,
#   'Lng': 94.7667,
#   'Max Temp': 57.67,
#   'Humidity': 92,
#   'Cloudiness': 27,
#   'Wind Speed': 1.48,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Acajutla',
#   'Country': 'SV',
#   'Lat': 13.5928,
#   'Lng': -89.8275,
#   'Max Temp': 91.74,
#   'Humidity': 60,
#   'Cloudiness': 90,
#   'Wind Speed': 9.26,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Baghmara',
#   'Country': 'IN',
#   'Lat': 23.795,
#   'Lng': 86.2085,
#   'Max Temp': 68.11,
#   'Humidity': 63,
#   'Cloudiness': 8,
#   'Wind Speed': 2.86,
#   'Current Description': 'clear sky'},
#  {'City': 'Vilyuysk',
#   'Country': 'RU',
#   'Lat': 63.7553,
#   'Lng': 121.6247,
#   'Max Temp': 10.35,
#   'Humidity': 95,
#   'Cloudiness': 15,
#   'Wind Speed': 6.26,
#   'Current Description': 'few clouds'},
#  {'City': 'Igarka',
#   'Country': 'RU',
#   'Lat': 67.4667,
#   'Lng': 86.5833,
#   'Max Temp': -3.46,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 4.09,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Marsaxlokk',
#   'Country': 'MT',
#   'Lat': 35.8419,
#   'Lng': 14.5431,
#   'Max Temp': 67.08,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Current Description': 'light rain'},
#  {'City': 'Avanigadda',
#   'Country': 'IN',
#   'Lat': 16.0215,
#   'Lng': 80.9181,
#   'Max Temp': 75.72,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 3.85,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Keminmaa',
#   'Country': 'FI',
#   'Lat': 65.8596,
#   'Lng': 24.8228,
#   'Max Temp': 40.77,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Akureyri',
#   'Country': 'IS',
#   'Lat': 65.6835,
#   'Lng': -18.0878,
#   'Max Temp': 33.73,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 20.71,
#   'Current Description': 'light snow'},
#  {'City': 'Dauphin',
#   'Country': 'CA',
#   'Lat': 51.1494,
#   'Lng': -100.0502,
#   'Max Temp': 37.54,
#   'Humidity': 56,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Todos Santos',
#   'Country': 'MX',
#   'Lat': 23.45,
#   'Lng': -110.2167,
#   'Max Temp': 88.11,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 9.82,
#   'Current Description': 'clear sky'},
#  {'City': 'Wau',
#   'Country': 'SS',
#   'Lat': 7.7029,
#   'Lng': 27.9953,
#   'Max Temp': 76.8,
#   'Humidity': 74,
#   'Cloudiness': 15,
#   'Wind Speed': 1.03,
#   'Current Description': 'few clouds'},
#  {'City': 'Mitsamiouli',
#   'Country': 'KM',
#   'Lat': -11.3847,
#   'Lng': 43.2844,
#   'Max Temp': 78.82,
#   'Humidity': 80,
#   'Cloudiness': 8,
#   'Wind Speed': 11.43,
#   'Current Description': 'clear sky'},
#  {'City': 'Wahiawā',
#   'Country': 'US',
#   'Lat': 21.5028,
#   'Lng': -158.0236,
#   'Max Temp': 77.86,
#   'Humidity': 69,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Agios Vasileios',
#   'Country': 'GR',
#   'Lat': 37.8,
#   'Lng': 22.8,
#   'Max Temp': 60.3,
#   'Humidity': 75,
#   'Cloudiness': 5,
#   'Wind Speed': 3.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Jinji',
#   'Country': 'CN',
#   'Lat': 23.2281,
#   'Lng': 110.8261,
#   'Max Temp': 66,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.82,
#   'Current Description': 'overcast clouds'},
#  {'City': 'North Bend',
#   'Country': 'US',
#   'Lat': 43.4065,
#   'Lng': -124.2243,
#   'Max Temp': 61.25,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bud',
#   'Country': 'US',
#   'Lat': 39.447,
#   'Lng': -86.1758,
#   'Max Temp': 63.7,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 14.23,
#   'Current Description': 'clear sky'},
#  {'City': 'Itaueira',
#   'Country': 'BR',
#   'Lat': -7.6033,
#   'Lng': -43.0256,
#   'Max Temp': 95.68,
#   'Humidity': 23,
#   'Cloudiness': 79,
#   'Wind Speed': 4.5,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kununurra',
#   'Country': 'AU',
#   'Lat': -15.7667,
#   'Lng': 128.7333,
#   'Max Temp': 76.98,
#   'Humidity': 88,
#   'Cloudiness': 6,
#   'Wind Speed': 5.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Buin',
#   'Country': 'CL',
#   'Lat': -33.7333,
#   'Lng': -70.75,
#   'Max Temp': 79.12,
#   'Humidity': 31,
#   'Cloudiness': 100,
#   'Wind Speed': 9.17,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sheridan',
#   'Country': 'US',
#   'Lat': 44.8333,
#   'Lng': -106.9173,
#   'Max Temp': 36.01,
#   'Humidity': 60,
#   'Cloudiness': 90,
#   'Wind Speed': 3,
#   'Current Description': 'light rain'},
#  {'City': 'Broken Hill',
#   'Country': 'AU',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 62.31,
#   'Humidity': 25,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Le Port',
#   'Country': 'RE',
#   'Lat': -20.9373,
#   'Lng': 55.2919,
#   'Max Temp': 69.8,
#   'Humidity': 79,
#   'Cloudiness': 2,
#   'Wind Speed': 1.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Kanniyākumāri',
#   'Country': 'IN',
#   'Lat': 8.0833,
#   'Lng': 77.5667,
#   'Max Temp': 79.03,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 4.56,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Fālākāta',
#   'Country': 'IN',
#   'Lat': 26.5208,
#   'Lng': 89.2055,
#   'Max Temp': 66.58,
#   'Humidity': 80,
#   'Cloudiness': 6,
#   'Wind Speed': 4.25,
#   'Current Description': 'clear sky'},
#  {'City': 'Tlapehuala',
#   'Country': 'MX',
#   'Lat': 18.2167,
#   'Lng': -100.5167,
#   'Max Temp': 85.37,
#   'Humidity': 64,
#   'Cloudiness': 97,
#   'Wind Speed': 1.28,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kollam',
#   'Country': 'IN',
#   'Lat': 8.8833,
#   'Lng': 76.6,
#   'Max Temp': 76.87,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 2.64,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Karasburg',
#   'Country': 'NA',
#   'Lat': -28.0167,
#   'Lng': 18.75,
#   'Max Temp': 62.49,
#   'Humidity': 55,
#   'Cloudiness': 7,
#   'Wind Speed': 19.19,
#   'Current Description': 'clear sky'},
#  {'City': 'Araripe',
#   'Country': 'BR',
#   'Lat': -7.2125,
#   'Lng': -40.0461,
#   'Max Temp': 82.85,
#   'Humidity': 40,
#   'Cloudiness': 100,
#   'Wind Speed': 4.32,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Abong Mbang',
#   'Country': 'CM',
#   'Lat': 3.9833,
#   'Lng': 13.1833,
#   'Max Temp': 68.99,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Current Description': 'light rain'},
#  {'City': 'Alamosa',
#   'Country': 'US',
#   'Lat': 37.4695,
#   'Lng': -105.87,
#   'Max Temp': 49.98,
#   'Humidity': 32,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Tomohon',
#   'Country': 'ID',
#   'Lat': 1.3346,
#   'Lng': 124.8392,
#   'Max Temp': 65.34,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 1.97,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Puerto Ayacucho',
#   'Country': 'VE',
#   'Lat': 5.6639,
#   'Lng': -67.6236,
#   'Max Temp': 83.21,
#   'Humidity': 74,
#   'Cloudiness': 72,
#   'Wind Speed': 4.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Gemeente Wageningen',
#   'Country': 'NL',
#   'Lat': 51.9667,
#   'Lng': 5.6667,
#   'Max Temp': 55.17,
#   'Humidity': 90,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Goderich',
#   'Country': 'CA',
#   'Lat': 43.7501,
#   'Lng': -81.7165,
#   'Max Temp': 53.91,
#   'Humidity': 76,
#   'Cloudiness': 4,
#   'Wind Speed': 11.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Saurimo',
#   'Country': 'AO',
#   'Lat': -9.6608,
#   'Lng': 20.3916,
#   'Max Temp': 64.71,
#   'Humidity': 85,
#   'Cloudiness': 95,
#   'Wind Speed': 1.92,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ishigaki',
#   'Country': 'JP',
#   'Lat': 24.3448,
#   'Lng': 124.1572,
#   'Max Temp': 76.82,
#   'Humidity': 66,
#   'Cloudiness': 42,
#   'Wind Speed': 16.53,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Novo Selo',
#   'Country': 'MK',
#   'Lat': 41.4139,
#   'Lng': 22.8811,
#   'Max Temp': 49.53,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 1.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Belmonte',
#   'Country': 'BR',
#   'Lat': -15.8631,
#   'Lng': -38.8828,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 47,
#   'Wind Speed': 8.52,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Khovd',
#   'Country': 'MN',
#   'Lat': 48.0056,
#   'Lng': 91.6419,
#   'Max Temp': 37.04,
#   'Humidity': 46,
#   'Cloudiness': 100,
#   'Wind Speed': 13.47,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gwanda',
#   'Country': 'ZW',
#   'Lat': -20.9333,
#   'Lng': 29,
#   'Max Temp': 73.47,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 10.13,
#   'Current Description': 'clear sky'},
#  {'City': 'Abu Dhabi',
#   'Country': 'AE',
#   'Lat': 24.4667,
#   'Lng': 54.3667,
#   'Max Temp': 84.31,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Abhā',
#   'Country': 'SA',
#   'Lat': 18.2164,
#   'Lng': 42.5053,
#   'Max Temp': 62.85,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Roebourne',
#   'Country': 'AU',
#   'Lat': -20.7833,
#   'Lng': 117.1333,
#   'Max Temp': 71.46,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 6.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Teya',
#   'Country': 'RU',
#   'Lat': 60.3778,
#   'Lng': 92.6267,
#   'Max Temp': 21.85,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Current Description': 'light snow'},
#  {'City': 'Zhangye',
#   'Country': 'CN',
#   'Lat': 38.9342,
#   'Lng': 100.4517,
#   'Max Temp': 43.11,
#   'Humidity': 37,
#   'Cloudiness': 100,
#   'Wind Speed': 5.32,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Santa Cruz de Tenerife',
#   'Country': 'ES',
#   'Lat': 28.4682,
#   'Lng': -16.2546,
#   'Max Temp': 75.69,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Spasskoye',
#   'Country': 'RU',
#   'Lat': 44.6108,
#   'Lng': 132.7969,
#   'Max Temp': 34.84,
#   'Humidity': 83,
#   'Cloudiness': 79,
#   'Wind Speed': 5.32,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sur',
#   'Country': 'OM',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 82.31,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 10.02,
#   'Current Description': 'clear sky'},
#  {'City': 'Liku',
#   'Country': 'ID',
#   'Lat': -0.7275,
#   'Lng': 119.8922,
#   'Max Temp': 75.94,
#   'Humidity': 85,
#   'Cloudiness': 98,
#   'Wind Speed': 2.35,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Anadyr',
#   'Country': 'RU',
#   'Lat': 64.75,
#   'Lng': 177.4833,
#   'Max Temp': -5.01,
#   'Humidity': 76,
#   'Cloudiness': 20,
#   'Wind Speed': 8.01,
#   'Current Description': 'light snow'},
#  {'City': 'Jizan',
#   'Country': 'SA',
#   'Lat': 17.3333,
#   'Lng': 42.6667,
#   'Max Temp': 88.74,
#   'Humidity': 62,
#   'Cloudiness': 5,
#   'Wind Speed': 2.46,
#   'Current Description': 'clear sky'},
#  {'City': 'Januária',
#   'Country': 'BR',
#   'Lat': -15.4833,
#   'Lng': -44.3667,
#   'Max Temp': 83.55,
#   'Humidity': 47,
#   'Cloudiness': 99,
#   'Wind Speed': 2.44,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Isla Vista',
#   'Country': 'US',
#   'Lat': 34.4133,
#   'Lng': -119.861,
#   'Max Temp': 75.34,
#   'Humidity': 73,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Current Description': 'haze'},
#  {'City': 'University Place',
#   'Country': 'US',
#   'Lat': 47.2356,
#   'Lng': -122.5504,
#   'Max Temp': 60.21,
#   'Humidity': 57,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Ocós',
#   'Country': 'GT',
#   'Lat': 14.5094,
#   'Lng': -92.1933,
#   'Max Temp': 88.3,
#   'Humidity': 69,
#   'Cloudiness': 22,
#   'Wind Speed': 6.42,
#   'Current Description': 'few clouds'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
weather_data_df = pd.DataFrame(city_data)
weather_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Barrow      US  71.2906 -156.7887     28.42        86          90
# 1         Umluj      SA  25.0213   37.2685     85.05        54          97
# 2        Atuona      PF  -9.8000 -139.0333     78.71        78           4
# 3        Iberia      US  29.9502  -91.7507     76.96        43           1
# 4  Beringovskiy      RU  63.0500  179.3167      6.53        92          97
# 5         Nyrob      RU  60.7330   56.7202     37.45        98         100
# 6       Mataura      NZ -46.1927  168.8643     49.87        57          82
# 7       Ushuaia      AR -54.8000  -68.3000     56.86        38           0
# 8        Avarua      CK -21.2078 -159.7750     75.25        69          90
# 9       Baoning      CN  25.3378  110.0260     60.66       100          90
#
#    Wind Speed Current Description
# 0       19.57                mist
# 1        4.99     overcast clouds
# 2       21.16           clear sky
# 3        6.91           clear sky
# 4       12.59     overcast clouds
# 5        8.68     overcast clouds
# 6        3.98          light rain
# 7        0.00           clear sky
# 8        9.22          light rain
# 9        4.47                mist

# %%
# Save Data to csv
weather_data_df.to_csv("WeatherPy_Database.csv")
